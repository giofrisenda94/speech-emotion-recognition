# %% [markdown]
# # RNN 4 Layer Model

# %%
import pandas
import numpy
import tensorflow
from tensorflow.keras import layers, models

# %% [markdown]
# ### Model Diagram

# %% [markdown]
# ![Model-4-Layer.png](attachment:Model-4-Layer.png)

# %% [markdown]
# ### Initiate Model

# %%
model_RNN_4 = models.Sequential()

#Input 399 Simple RNN Layer
model_RNN_4.add(layers.SimpleRNN(units=399, activation='tanh', input_shape=(ADD_INPUT_SHAPE)))


#Hidden 64 LSTM Layer
model_RNN_4.add(LSTM(units=64, activation='tanh'))


#Hidden 64 LSTM Layer
model_RNN_4.add(LSTM(units=64, activation='tanh'))


#Output 8 Dense RELU Layer
model_RNN_4.add(Dense(3, activation = "softmax"))
# Out:
# 2022-08-29 17:05:38.914580: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
